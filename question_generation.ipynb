# %% [markdown]
# # `convert_text_to_opennmt_format.py`

# %%
import json
import copy
from pycorenlp import StanfordCoreNLP
from sys import argv
from pprint import pprint as pprint

nlp = StanfordCoreNLP('http://localhost:9000')

# %%
# !cat ./data/ner_features
with open('data/sample_short.txt', 'r') as myfile:
    text = myfile.read()
print(text)
# Out:
# DATE	1
# DURATION	2
# LOCATION	3
# MISC	4
# MONEY	5
# NUMBER	6
# O	7
# ORDINAL	8
# ORGANIZATION	9
# PADDING	10
# PERCENT	11
# PERSON	12
# TIME	13
# Singapore was declared independent on 9 August 1965.
# National Service lasts two years.
# The tuition fee for NUS engineering course is $8000 per year.

# %%
output = nlp.annotate(text, properties={
    'annotators': 'tokenize,ssplit,pos,ner',
    'outputFormat': 'json'}
)
if type(output) == str:
    output =json.loads(output, encoding='utf-8', strict=False)
pprint(output)
# Out:
# {'sentences': [{'index': 0,
#                 'parse': 'SENTENCE_SKIPPED_OR_UNPARSABLE',
#                 'tokens': [{'after': ' ',
#                             'before': '',
#                             'characterOffsetBegin': 0,
#                             'characterOffsetEnd': 9,
#                             'index': 1,
#                             'lemma': 'Singapore',
#                             'ner': 'LOCATION',
#                             'originalText': 'Singapore',
#                             'pos': 'NNP',
#                             'word': 'Singapore'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 10,
#                             'characterOffsetEnd': 13,
#                             'index': 2,
#                             'lemma': 'be',
#                             'ner': 'O',
#                             'originalText': 'was',
#                             'pos': 'VBD',
#                             'word': 'was'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 14,
#                             'characterOffsetEnd': 22,
#                             'index': 3,
#                             'lemma': 'declare',
#                             'ner': 'O',
#                             'originalText': 'declared',
#                             'pos': 'VBN',
#                             'word': 'declared'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 23,
#                             'characterOffsetEnd': 34,
#                             'index': 4,
#                             'lemma': 'independent',
#                             'ner': 'O',
#                             'originalText': 'independent',
#                             'pos': 'JJ',
#                             'word': 'independent'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 35,
#                             'characterOffsetEnd': 37,
#                             'index': 5,
#                             'lemma': 'on',
#                             'ner': 'O',
#                             'originalText': 'on',
#                             'pos': 'IN',
#                             'word': 'on'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 38,
#                             'characterOffsetEnd': 39,
#                             'index': 6,
#                             'lemma': '9',
#                             'ner': 'DATE',
#                             'normalizedNER': '1965-08-09',
#                             'originalText': '9',
#                             'pos': 'CD',
#                             'timex': {'tid': 't1',
#                                       'type': 'DATE',
#                                       'value': '1965-08-09'},
#                             'word': '9'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 40,
#                             'characterOffsetEnd': 46,
#                             'index': 7,
#                             'lemma': 'August',
#                             'ner': 'DATE',
#                             'normalizedNER': '1965-08-09',
#                             'originalText': 'August',
#                             'pos': 'NNP',
#                             'timex': {'tid': 't1',
#                                       'type': 'DATE',
#                                       'value': '1965-08-09'},
#                             'word': 'August'},
#                            {'after': '',
#                             'before': ' ',
#                             'characterOffsetBegin': 47,
#                             'characterOffsetEnd': 51,
#                             'index': 8,
#                             'lemma': '1965',
#                             'ner': 'DATE',
#                             'normalizedNER': '1965-08-09',
#                             'originalText': '1965',
#                             'pos': 'CD',
#                             'timex': {'tid': 't1',
#                                       'type': 'DATE',
#                                       'value': '1965-08-09'},
#                             'word': '1965'},
#                            {'after': ' \n',
#                             'before': '',
#                             'characterOffsetBegin': 51,
#                             'characterOffsetEnd': 52,
#                             'index': 9,
#                             'lemma': '.',
#                             'ner': 'O',
#                             'originalText': '.',
#                             'pos': '.',
#                             'word': '.'}]},
#                {'index': 1,
#                 'parse': 'SENTENCE_SKIPPED_OR_UNPARSABLE',
#                 'tokens': [{'after': ' ',
#                             'before': ' \n',
#                             'characterOffsetBegin': 54,
#                             'characterOffsetEnd': 62,
#                             'index': 1,
#                             'lemma': 'National',
#                             'ner': 'ORGANIZATION',
#                             'originalText': 'National',
#                             'pos': 'NNP',
#                             'word': 'National'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 63,
#                             'characterOffsetEnd': 70,
#                             'index': 2,
#                             'lemma': 'Service',
#                             'ner': 'ORGANIZATION',
#                             'originalText': 'Service',
#                             'pos': 'NNP',
#                             'word': 'Service'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 71,
#                             'characterOffsetEnd': 76,
#                             'index': 3,
#                             'lemma': 'last',
#                             'ner': 'O',
#                             'originalText': 'lasts',
#                             'pos': 'VBZ',
#                             'word': 'lasts'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 77,
#                             'characterOffsetEnd': 80,
#                             'index': 4,
#                             'lemma': 'two',
#                             'ner': 'DURATION',
#                             'normalizedNER': 'P2Y',
#                             'originalText': 'two',
#                             'pos': 'CD',
#                             'timex': {'tid': 't2',
#                                       'type': 'DURATION',
#                                       'value': 'P2Y'},
#                             'word': 'two'},
#                            {'after': '',
#                             'before': ' ',
#                             'characterOffsetBegin': 81,
#                             'characterOffsetEnd': 86,
#                             'index': 5,
#                             'lemma': 'year',
#                             'ner': 'DURATION',
#                             'normalizedNER': 'P2Y',
#                             'originalText': 'years',
#                             'pos': 'NNS',
#                             'timex': {'tid': 't2',
#                                       'type': 'DURATION',
#                                       'value': 'P2Y'},
#                             'word': 'years'},
#                            {'after': ' \n',
#                             'before': '',
#                             'characterOffsetBegin': 86,
#                             'characterOffsetEnd': 87,
#                             'index': 6,
#                             'lemma': '.',
#                             'ner': 'O',
#                             'originalText': '.',
#                             'pos': '.',
#                             'word': '.'}]},
#                {'index': 2,
#                 'parse': 'SENTENCE_SKIPPED_OR_UNPARSABLE',
#                 'tokens': [{'after': ' ',
#                             'before': ' \n',
#                             'characterOffsetBegin': 89,
#                             'characterOffsetEnd': 92,
#                             'index': 1,
#                             'lemma': 'the',
#                             'ner': 'O',
#                             'originalText': 'The',
#                             'pos': 'DT',
#                             'word': 'The'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 93,
#                             'characterOffsetEnd': 100,
#                             'index': 2,
#                             'lemma': 'tuition',
#                             'ner': 'O',
#                             'originalText': 'tuition',
#                             'pos': 'NN',
#                             'word': 'tuition'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 101,
#                             'characterOffsetEnd': 104,
#                             'index': 3,
#                             'lemma': 'fee',
#                             'ner': 'O',
#                             'originalText': 'fee',
#                             'pos': 'NN',
#                             'word': 'fee'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 105,
#                             'characterOffsetEnd': 108,
#                             'index': 4,
#                             'lemma': 'for',
#                             'ner': 'O',
#                             'originalText': 'for',
#                             'pos': 'IN',
#                             'word': 'for'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 109,
#                             'characterOffsetEnd': 112,
#                             'index': 5,
#                             'lemma': 'NUS',
#                             'ner': 'ORGANIZATION',
#                             'originalText': 'NUS',
#                             'pos': 'NNP',
#                             'word': 'NUS'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 113,
#                             'characterOffsetEnd': 124,
#                             'index': 6,
#                             'lemma': 'engineering',
#                             'ner': 'O',
#                             'originalText': 'engineering',
#                             'pos': 'NN',
#                             'word': 'engineering'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 125,
#                             'characterOffsetEnd': 131,
#                             'index': 7,
#                             'lemma': 'course',
#                             'ner': 'O',
#                             'originalText': 'course',
#                             'pos': 'NN',
#                             'word': 'course'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 132,
#                             'characterOffsetEnd': 134,
#                             'index': 8,
#                             'lemma': 'be',
#                             'ner': 'O',
#                             'originalText': 'is',
#                             'pos': 'VBZ',
#                             'word': 'is'},
#                            {'after': '',
#                             'before': ' ',
#                             'characterOffsetBegin': 135,
#                             'characterOffsetEnd': 136,
#                             'index': 9,
#                             'lemma': '$',
#                             'ner': 'MONEY',
#                             'normalizedNER': '$8000.0',
#                             'originalText': '$',
#                             'pos': '$',
#                             'word': '$'},
#                            {'after': ' ',
#                             'before': '',
#                             'characterOffsetBegin': 136,
#                             'characterOffsetEnd': 140,
#                             'index': 10,
#                             'lemma': '8000',
#                             'ner': 'MONEY',
#                             'normalizedNER': '$8000.0',
#                             'originalText': '8000',
#                             'pos': 'CD',
#                             'word': '8000'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 141,
#                             'characterOffsetEnd': 144,
#                             'index': 11,
#                             'lemma': 'per',
#                             'ner': 'O',
#                             'originalText': 'per',
#                             'pos': 'IN',
#                             'word': 'per'},
#                            {'after': '',
#                             'before': ' ',
#                             'characterOffsetBegin': 145,
#                             'characterOffsetEnd': 149,
#                             'index': 12,
#                             'lemma': 'year',
#                             'ner': 'DURATION',
#                             'normalizedNER': 'P1Y',
#                             'originalText': 'year',
#                             'pos': 'NN',
#                             'timex': {'tid': 't3',
#                                       'type': 'DURATION',
#                                       'value': 'P1Y'},
#                             'word': 'year'},
#                            {'after': '',
#                             'before': '',
#                             'characterOffsetBegin': 149,
#                             'characterOffsetEnd': 150,
#                             'index': 13,
#                             'lemma': '.',
#                             'ner': 'O',
#                             'originalText': '.',
#                             'pos': '.',
#                             'word': '.'}]}]}

# %%
def get_possible_ans_tags(ner_features_path='data/ner_features'):
    with open(ner_features_path, 'r') as f:
        possible_ans_tags = [line.split('\t')[0] for line in f]
    possible_ans_tags = [tag for tag in possible_ans_tags if tag != 'O']
    possible_ans_tags.append('CD')
    possible_ans_tags = set(possible_ans_tags)
    return possible_ans_tags

possible_ans_tags = get_possible_ans_tags()
pprint(possible_ans_tags)
# Out:
# {'CD',
#  'DATE',
#  'DURATION',
#  'LOCATION',
#  'MISC',
#  'MONEY',
#  'NUMBER',
#  'ORDINAL',
#  'ORGANIZATION',
#  'PADDING',
#  'PERCENT',
#  'PERSON',
#  'TIME'}

# %%
def get_featured_sents(corenlp_output):
    sents = []
    for sentence in corenlp_output['sentences']:
        sent_start_ind = sentence['index']
        sent = []
        for token in sentence['tokens']:
            token_start_ind = token['index']
            word = token['originalText']
            lower_word = word.lower()
            if (word[0] == word[0].upper() and word[0] != word[0].lower()):
                case_tag = 'UP'
            else:
                case_tag = 'LOW'
            ner_tag = token['ner']
            pos_tag = token['pos']
            sent.append(({'token': lower_word, 'ner': ner_tag, 'case_tag': case_tag, 'pos_tag': pos_tag}))
        sents.append(sent)
    return sents
sents = get_featured_sents(output)
pprint(sents)
# Out:
# [[{'case_tag': 'UP', 'ner': 'LOCATION', 'pos_tag': 'NNP', 'token': 'singapore'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'VBD', 'token': 'was'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'VBN', 'token': 'declared'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'JJ', 'token': 'independent'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'IN', 'token': 'on'},
#   {'case_tag': 'LOW', 'ner': 'DATE', 'pos_tag': 'CD', 'token': '9'},
#   {'case_tag': 'UP', 'ner': 'DATE', 'pos_tag': 'NNP', 'token': 'august'},
#   {'case_tag': 'LOW', 'ner': 'DATE', 'pos_tag': 'CD', 'token': '1965'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': '.', 'token': '.'}],
#  [{'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'national'},
#   {'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'service'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'VBZ', 'token': 'lasts'},
#   {'case_tag': 'LOW', 'ner': 'DURATION', 'pos_tag': 'CD', 'token': 'two'},
#   {'case_tag': 'LOW', 'ner': 'DURATION', 'pos_tag': 'NNS', 'token': 'years'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': '.', 'token': '.'}],
#  [{'case_tag': 'UP', 'ner': 'O', 'pos_tag': 'DT', 'token': 'the'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'NN', 'token': 'tuition'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'NN', 'token': 'fee'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'IN', 'token': 'for'},
#   {'case_tag': 'UP', 'ner': 'ORGANIZATION', 'pos_tag': 'NNP', 'token': 'nus'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'NN', 'token': 'engineering'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'NN', 'token': 'course'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'VBZ', 'token': 'is'},
#   {'case_tag': 'LOW', 'ner': 'MONEY', 'pos_tag': '$', 'token': '$'},
#   {'case_tag': 'LOW', 'ner': 'MONEY', 'pos_tag': 'CD', 'token': '8000'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'IN', 'token': 'per'},
#   {'case_tag': 'LOW', 'ner': 'DURATION', 'pos_tag': 'NN', 'token': 'year'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': '.', 'token': '.'}]]

# %%
def add_answers_tag(sents, possible_ans_tags):
    for sent in sents:
        ans_tag = 'O'
        for token in sent:
            if token['ner'] in possible_ans_tags or token['pos_tag'] in possible_ans_tags:
                if ans_tag == 'B' or ans_tag == 'I':
                    ans_tag = 'I'
                else:
                    ans_tag = 'B'
            else:
                ans_tag = 'O'
            token['ans_tag'] = ans_tag
add_answers_tag(sents, possible_ans_tags)
pprint(sents)
# Out:
# [[{'ans_tag': 'B',
#    'case_tag': 'UP',
#    'ner': 'LOCATION',
#    'pos_tag': 'NNP',
#    'token': 'singapore'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBD',
#    'token': 'was'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBN',
#    'token': 'declared'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'JJ',
#    'token': 'independent'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'on'},
#   {'ans_tag': 'B',
#    'case_tag': 'LOW',
#    'ner': 'DATE',
#    'pos_tag': 'CD',
#    'token': '9'},
#   {'ans_tag': 'I',
#    'case_tag': 'UP',
#    'ner': 'DATE',
#    'pos_tag': 'NNP',
#    'token': 'august'},
#   {'ans_tag': 'I',
#    'case_tag': 'LOW',
#    'ner': 'DATE',
#    'pos_tag': 'CD',
#    'token': '1965'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': '.',
#    'token': '.'}],
#  [{'ans_tag': 'B',
#    'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'national'},
#   {'ans_tag': 'I',
#    'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'service'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBZ',
#    'token': 'lasts'},
#   {'ans_tag': 'B',
#    'case_tag': 'LOW',
#    'ner': 'DURATION',
#    'pos_tag': 'CD',
#    'token': 'two'},
#   {'ans_tag': 'I',
#    'case_tag': 'LOW',
#    'ner': 'DURATION',
#    'pos_tag': 'NNS',
#    'token': 'years'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': '.',
#    'token': '.'}],
#  [{'ans_tag': 'O',
#    'case_tag': 'UP',
#    'ner': 'O',
#    'pos_tag': 'DT',
#    'token': 'the'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'tuition'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'fee'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'for'},
#   {'ans_tag': 'B',
#    'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'nus'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'engineering'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'course'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBZ',
#    'token': 'is'},
#   {'ans_tag': 'B',
#    'case_tag': 'LOW',
#    'ner': 'MONEY',
#    'pos_tag': '$',
#    'token': '$'},
#   {'ans_tag': 'I',
#    'case_tag': 'LOW',
#    'ner': 'MONEY',
#    'pos_tag': 'CD',
#    'token': '8000'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'per'},
#   {'ans_tag': 'B',
#    'case_tag': 'LOW',
#    'ner': 'DURATION',
#    'pos_tag': 'NN',
#    'token': 'year'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': '.',
#    'token': '.'}]]

# %%
def copy_sent_with_one_ans(sent, begin_ind, end_ind):
    new_sent = copy.deepcopy(sent)
    for ind, token in enumerate(new_sent):
        if ind < begin_ind or ind > end_ind:
            token['ans_tag'] = 'O'
    return new_sent

def separate_and_duplicate_ans_sents(sents):
    new_sents = []
    for sent in sents:
        begin_ind, end_ind = None, None
        for ind, token in enumerate(sent):
            if token['ans_tag'] == 'B':
                begin_ind = ind
            elif token['ans_tag'] == 'I':
                continue
            else:
                if begin_ind is not None:
                    end_ind = ind - 1
                    new_sent = copy_sent_with_one_ans(sent, begin_ind, end_ind)
                    begin_ind = None
                    new_sents.append(new_sent)
                else:
                    begin_ind, end_ind = None, None
    return new_sents
sents = separate_and_duplicate_ans_sents(sents)
pprint(sents)
# Out:
# [[{'ans_tag': 'B',
#    'case_tag': 'UP',
#    'ner': 'LOCATION',
#    'pos_tag': 'NNP',
#    'token': 'singapore'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBD',
#    'token': 'was'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBN',
#    'token': 'declared'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'JJ',
#    'token': 'independent'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'on'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'DATE',
#    'pos_tag': 'CD',
#    'token': '9'},
#   {'ans_tag': 'O',
#    'case_tag': 'UP',
#    'ner': 'DATE',
#    'pos_tag': 'NNP',
#    'token': 'august'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'DATE',
#    'pos_tag': 'CD',
#    'token': '1965'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': '.',
#    'token': '.'}],
#  [{'ans_tag': 'O',
#    'case_tag': 'UP',
#    'ner': 'LOCATION',
#    'pos_tag': 'NNP',
#    'token': 'singapore'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBD',
#    'token': 'was'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBN',
#    'token': 'declared'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'JJ',
#    'token': 'independent'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'on'},
#   {'ans_tag': 'B',
#    'case_tag': 'LOW',
#    'ner': 'DATE',
#    'pos_tag': 'CD',
#    'token': '9'},
#   {'ans_tag': 'I',
#    'case_tag': 'UP',
#    'ner': 'DATE',
#    'pos_tag': 'NNP',
#    'token': 'august'},
#   {'ans_tag': 'I',
#    'case_tag': 'LOW',
#    'ner': 'DATE',
#    'pos_tag': 'CD',
#    'token': '1965'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': '.',
#    'token': '.'}],
#  [{'ans_tag': 'B',
#    'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'national'},
#   {'ans_tag': 'I',
#    'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'service'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBZ',
#    'token': 'lasts'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'DURATION',
#    'pos_tag': 'CD',
#    'token': 'two'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'DURATION',
#    'pos_tag': 'NNS',
#    'token': 'years'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': '.',
#    'token': '.'}],
#  [{'ans_tag': 'O',
#    'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'national'},
#   {'ans_tag': 'O',
#    'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'service'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBZ',
#    'token': 'lasts'},
#   {'ans_tag': 'B',
#    'case_tag': 'LOW',
#    'ner': 'DURATION',
#    'pos_tag': 'CD',
#    'token': 'two'},
#   {'ans_tag': 'I',
#    'case_tag': 'LOW',
#    'ner': 'DURATION',
#    'pos_tag': 'NNS',
#    'token': 'years'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': '.',
#    'token': '.'}],
#  [{'ans_tag': 'O',
#    'case_tag': 'UP',
#    'ner': 'O',
#    'pos_tag': 'DT',
#    'token': 'the'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'tuition'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'fee'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'for'},
#   {'ans_tag': 'B',
#    'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'nus'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'engineering'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'course'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBZ',
#    'token': 'is'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'MONEY',
#    'pos_tag': '$',
#    'token': '$'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'MONEY',
#    'pos_tag': 'CD',
#    'token': '8000'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'per'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'DURATION',
#    'pos_tag': 'NN',
#    'token': 'year'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': '.',
#    'token': '.'}],
#  [{'ans_tag': 'O',
#    'case_tag': 'UP',
#    'ner': 'O',
#    'pos_tag': 'DT',
#    'token': 'the'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'tuition'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'fee'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'for'},
#   {'ans_tag': 'O',
#    'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'nus'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'engineering'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'course'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBZ',
#    'token': 'is'},
#   {'ans_tag': 'B',
#    'case_tag': 'LOW',
#    'ner': 'MONEY',
#    'pos_tag': '$',
#    'token': '$'},
#   {'ans_tag': 'I',
#    'case_tag': 'LOW',
#    'ner': 'MONEY',
#    'pos_tag': 'CD',
#    'token': '8000'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'per'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'DURATION',
#    'pos_tag': 'NN',
#    'token': 'year'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': '.',
#    'token': '.'}],
#  [{'ans_tag': 'O',
#    'case_tag': 'UP',
#    'ner': 'O',
#    'pos_tag': 'DT',
#    'token': 'the'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'tuition'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'fee'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'for'},
#   {'ans_tag': 'O',
#    'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'nus'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'engineering'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'course'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBZ',
#    'token': 'is'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'MONEY',
#    'pos_tag': '$',
#    'token': '$'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'MONEY',
#    'pos_tag': 'CD',
#    'token': '8000'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'per'},
#   {'ans_tag': 'B',
#    'case_tag': 'LOW',
#    'ner': 'DURATION',
#    'pos_tag': 'NN',
#    'token': 'year'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': '.',
#    'token': '.'}]]

# %%
def convert_sents_to_opennmt(sents):
    featured_sents = []
    for sent in sents:
        featured_source_tokens = []
        for token in sent:
            featured_source_token = "{}￨{}￨{}￨{}￨{}".format(
                token['token'],
                token['ans_tag'],
                token['case_tag'],
                token['pos_tag'],
                token['ner']
            )
            featured_source_tokens.append(featured_source_token)
        featured_sents.append(" ".join(featured_source_tokens))
    return featured_sents
opennmt_sents = convert_sents_to_opennmt(sents)
for sent in opennmt_sents:
    print(sent)
    # this output is piped to get qnas.py
# Out:
# singapore￨B￨UP￨NNP￨LOCATION was￨O￨LOW￨VBD￨O declared￨O￨LOW￨VBN￨O independent￨O￨LOW￨JJ￨O on￨O￨LOW￨IN￨O 9￨O￨LOW￨CD￨DATE august￨O￨UP￨NNP￨DATE 1965￨O￨LOW￨CD￨DATE .￨O￨LOW￨.￨O
# singapore￨O￨UP￨NNP￨LOCATION was￨O￨LOW￨VBD￨O declared￨O￨LOW￨VBN￨O independent￨O￨LOW￨JJ￨O on￨O￨LOW￨IN￨O 9￨B￨LOW￨CD￨DATE august￨I￨UP￨NNP￨DATE 1965￨I￨LOW￨CD￨DATE .￨O￨LOW￨.￨O
# national￨B￨UP￨NNP￨ORGANIZATION service￨I￨UP￨NNP￨ORGANIZATION lasts￨O￨LOW￨VBZ￨O two￨O￨LOW￨CD￨DURATION years￨O￨LOW￨NNS￨DURATION .￨O￨LOW￨.￨O
# national￨O￨UP￨NNP￨ORGANIZATION service￨O￨UP￨NNP￨ORGANIZATION lasts￨O￨LOW￨VBZ￨O two￨B￨LOW￨CD￨DURATION years￨I￨LOW￨NNS￨DURATION .￨O￨LOW￨.￨O
# the￨O￨UP￨DT￨O tuition￨O￨LOW￨NN￨O fee￨O￨LOW￨NN￨O for￨O￨LOW￨IN￨O nus￨B￨UP￨NNP￨ORGANIZATION engineering￨O￨LOW￨NN￨O course￨O￨LOW￨NN￨O is￨O￨LOW￨VBZ￨O $￨O￨LOW￨$￨MONEY 8000￨O￨LOW￨CD￨MONEY per￨O￨LOW￨IN￨O year￨O￨LOW￨NN￨DURATION .￨O￨LOW￨.￨O
# the￨O￨UP￨DT￨O tuition￨O￨LOW￨NN￨O fee￨O￨LOW￨NN￨O for￨O￨LOW￨IN￨O nus￨O￨UP￨NNP￨ORGANIZATION engineering￨O￨LOW￨NN￨O course￨O￨LOW￨NN￨O is￨O￨LOW￨VBZ￨O $￨B￨LOW￨$￨MONEY 8000￨I￨LOW￨CD￨MONEY per￨O￨LOW￨IN￨O year￨O￨LOW￨NN￨DURATION .￨O￨LOW￨.￨O
# the￨O￨UP￨DT￨O tuition￨O￨LOW￨NN￨O fee￨O￨LOW￨NN￨O for￨O￨LOW￨IN￨O nus￨O￨UP￨NNP￨ORGANIZATION engineering￨O￨LOW￨NN￨O course￨O￨LOW￨NN￨O is￨O￨LOW￨VBZ￨O $￨O￨LOW￨$￨MONEY 8000￨O￨LOW￨CD￨MONEY per￨O￨LOW￨IN￨O year￨B￨LOW￨NN￨DURATION .￨O￨LOW￨.￨O

# %% [markdown]
# # `get_qna.py`

# %%
# -*- coding: utf-8 -*-
import zmq, sys, json
from signal import signal, SIGPIPE, SIG_DFL

# %%
data = [{"src": line} for line in opennmt_sents]

# %%
class ConnectionHandler:
    def __init__(self):
        signal(SIGPIPE, SIG_DFL)
        self.sock = zmq.Context().socket(zmq.REQ)
        self.sock.connect("tcp://127.0.0.1:5556")

    def __call__(self, data):
        self.sock.send_string(json.dumps(data))
        recieved = json.loads(str(self.sock.recv(), "utf-8"), encoding='utf-8', strict=False)
        print("Output from openmnt \n")
        pprint(recieved)
        print("\n\n\n\n")
        recieved = [(row[0]['tgt'], row[0]['pred_score'], row[0]['src']) for row in recieved]
        print("Output that is relevant")
        pprint(recieved)
        print("\n\n\n\n")
        return get_with_answers(recieved)

# does this merely process the answers?
def get_with_answers(recieved):
    answers = []
    for _, _, src in recieved:
        tokens = src.split(' ')
        answer = []
        for token in tokens:
            features = token.split('￨')
            word = features[0]
            ans_tag = features[1]
            if ans_tag == 'B' or ans_tag == 'I':
                answer.append(word)
            elif answer:
                break
        answers.append(' '.join(answer))
    return [(recieved[i][0], answers[i], recieved[i][1]) for i in range(len(recieved))]

# %%
connect = ConnectionHandler()
received = connect(data)

for target, answer, score in sorted(received, key=lambda x: x[2], reverse=True):
    print("{}\t{}\t{}".format(target, answer, score))
# Out:
# Output from openmnt
#
# [[{'attn': [[0.99102300405502,
#              0.0037460965104401,
#              0.00092615053290501,
#              0.0012628746917471,
#              0.0025424077175558,
#              5.9968009736622e-05,
#              9.4836314019631e-06,
#              1.78015743586e-05,
#              0.00041221251012757],
#             [1.4661324030385e-06,
#              0.11344105005264,
#              0.88650673627853,
#              4.9313908675686e-05,
#              3.0605920642301e-07,
#              1.1565532531677e-08,
#              7.572441007575e-10,
#              7.8667972136515e-10,
#              1.1150099226143e-06],
#             [2.7094037591269e-07,
#              3.2391406421084e-05,
#              0.99922150373459,
#              0.00074580480577424,
#              1.8678381508153e-08,
#              1.2291422324395e-09,
#              3.6530442559801e-10,
#              6.4651023423679e-10,
#              2.116089881099e-08],
#             [2.3581554486896e-09,
#              2.4916758434301e-07,
#              0.0009753170888871,
#              0.9987370967865,
#              0.00028412160463631,
#              2.6336823566453e-07,
#              1.7061615835701e-06,
#              2.8964401987963e-09,
#              1.2592954590218e-06],
#             [1.5035520846141e-06,
#              1.4223842015326e-07,
#              1.8817043212493e-07,
#              0.0018646729877219,
#              0.99474132061005,
#              0.0001140228487202,
#              0.0017437329515815,
#              5.8753630582942e-05,
#              0.0014756926102564],
#             [4.7093141830601e-08,
#              1.2389735903895e-09,
#              9.5551962175922e-11,
#              9.1972708560206e-07,
#              0.00034336946555413,
#              0.082107245922089,
#              0.91647708415985,
#              0.00085514836246148,
#              0.00021616918093059],
#             [2.1579257478144e-11,
#              5.9335947266703e-10,
#              3.6148729842811e-11,
#              1.9218457381065e-10,
#              9.1533074453309e-08,
#              0.00012899552530143,
#              0.66274684667587,
#              0.33343282341957,
#              0.0036912539508194],
#             [2.3454252429111e-10,
#              1.1369419850027e-09,
#              8.6837733184741e-12,
#              1.2685259093148e-11,
#              8.1667383966533e-09,
#              2.5693594579934e-05,
#              0.016346469521523,
#              0.7476704120636,
#              0.23595744371414]],
#    'n_best': 1,
#    'pred_score': -4.4853830337524,
#    'src': 'singapore￨B￨UP￨NNP￨LOCATION was￨O￨LOW￨VBD￨O declared￨O￨LOW￨VBN￨O '
#           'independent￨O￨LOW￨JJ￨O on￨O￨LOW￨IN￨O 9�
#              0.0001094309554901,
#              0.21550258994102,
#              0.013060957193375,
#              0.00018843905127142,
#              0.00015560440078843,
#              0.63660663366318,
#              0.006214389577508,
#              0.12269327789545],
#             [0.0035253893584013,
#              0.014463278464973,
#              0.0010600296081975,
#              0.00065419886959717,
#              0.028867209330201,
#              0.00084442360093817,
#              0.020056685432792,
#              0.00016541707736906,
#              0.00031090612174012,
#              0.0013847725931555,
#              0.0093006221577525,
#              0.91037863492966,
#              0.0089884353801608],
#             [0.080501578748226,
#              0.00062481150962412,
#              0.023370007053018,
#              0.61656105518341,
#              0.0071406126953661,
#              0.0010101719526574,
#              0.051533132791519,
#              0.20153512060642,
#              0.00017742998898029,
#              1.5532206816715e-05,
#              1.2415494893503e-05,
#              1.6217816778408e-07,
#              0.017517959699035]],
#    'n_best': 1,
#    'pred_score': -7.479350566864,
#    'src': 'the￨O￨UP￨DT￨O tuition￨O￨LOW￨NN￨O fee￨O￨LOW￨NN￨O for￨O￨LOW￨IN￨O '
#           'nus￨O￨UP￨NNP￨ORGANIZATION engineering￨O￨LOW￨NN￨O course￨O￨LOW￨NN￨O '
#           'is￨O￨LOW￨VBZ￨O $￨O￨LOW￨$￨MONEY 8000￨O￨LOW￨CD￨MONEY per￨O￨LOW￨IN￨O '
#           'year￨B￨LOW￨NN￨DURATION .￨O￨LOW￨.￨O',
#    'tgt': 'what is the amount of tuition per year ?'}]]
#
#
#
#
#
# Output that is relevant
# [('who was declared independent on august august ?',
#   -4.4853830337524,
#   'singapore￨B￨UP￨NNP￨LOCATION was￨O￨LOW￨VBD￨O declared￨O￨LOW￨VBN￨O '
#   'independent￨O￨LOW￨JJ￨O on￨O￨LOW￨IN￨O 9￨O￨LOW￨CD￨DATE august￨O￨UP￨NNP￨DATE '
#   '1965￨O￨LOW￨CD￨DATE .￨O￨LOW￨.￨O'),
#  ('when did singapore declare independence ?',
#   -3.1612322330475,
#   'singapore￨O￨UP￨NNP￨LOCATION was￨O￨LOW￨VBD￨O declared￨O￨LOW￨VBN￨O '
#   'independent￨O￨LOW￨JJ￨O on￨O￨LOW￨IN￨O 9￨B￨LOW￨CD￨DATE august￨I￨UP￨NNP￨DATE '
#   '1965￨I￨LOW￨CD￨DATE .￨O￨LOW￨.￨O'),
#  ('what is another name for two years ?',
#   -5.5310859680176,
#   'national￨B￨UP￨NNP￨ORGANIZATION service￨I￨UP￨NNP￨ORGANIZATION '
#   'lasts￨O￨LOW￨VBZ￨O two￨O￨LOW￨CD￨DURATION years￨O￨LOW￨NNS￨DURATION '
#   '.￨O￨LOW￨.￨O'),
#  ('how many years does national service last ?',
#   -2.7501549720764,
#   'national￨O￨UP￨NNP￨ORGANIZATION service￨O￨UP￨NNP￨ORGANIZATION '
#   'lasts￨O￨LOW￨VBZ￨O two￨B￨LOW￨CD￨DURATION years￨I￨LOW￨NNS￨DURATION '
#   '.￨O￨LOW￨.￨O'),
#  ('what kind of engineering course is covered by the university of kansas ?',
#   -13.651232719421,
#   'the￨O￨UP￨DT￨O tuition￨O￨LOW￨NN￨O fee￨O￨LOW￨NN￨O for￨O￨LOW￨IN￨O '
#   'nus￨B￨UP￨NNP￨ORGANIZATION engineering￨O￨LOW￨NN￨O course￨O￨LOW￨NN￨O '
#   'is￨O￨LOW￨VBZ￨O $￨O￨LOW￨$￨MONEY 8000￨O￨LOW￨CD￨MONEY per￨O￨LOW￨IN￨O '
#   'year￨O￨LOW￨NN￨DURATION .￨O￨LOW￨.￨O'),
#  ('how much is the glacial engineering course per year ?',
#   -8.2633075714111,
#   'the￨O￨UP￨DT￨O tuition￨O￨LOW￨NN￨O fee￨O￨LOW￨NN￨O for￨O￨LOW￨IN￨O '
#   'nus￨O￨UP￨NNP￨ORGANIZATION engineering￨O￨LOW￨NN￨O course￨O￨LOW￨NN￨O '
#   'is￨O￨LOW￨VBZ￨O $￨B￨LOW￨$￨MONEY 8000￨I￨LOW￨CD￨MONEY per￨O￨LOW￨IN￨O '
#   'year￨O￨LOW￨NN￨DURATION .￨O￨LOW￨.￨O'),
#  ('what is the amount of tuition per year ?',
#   -7.479350566864,
#   'the￨O￨UP￨DT￨O tuition￨O￨LOW￨NN￨O fee￨O￨LOW￨NN￨O for￨O￨LOW￨IN￨O '
#   'nus￨O￨UP￨NNP￨ORGANIZATION engineering￨O￨LOW￨NN￨O course￨O￨LOW￨NN￨O '
#   'is￨O￨LOW￨VBZ￨O $￨O￨LOW￨$￨MONEY 8000￨O￨LOW￨CD￨MONEY per￨O￨LOW￨IN￨O '
#   'year￨B￨LOW￨NN￨DURATION .￨O￨LOW￨.￨O')]
#
#
#
#
#
# how many years does national service last ?	two years	-2.7501549720764
# when did singapore declare independence ?	9 august 1965	-3.1612322330475
# who was declared independent on august august ?	singapore	-4.4853830337524
# what is another name for two years ?	national service	-5.5310859680176
# what is the amount of tuition per year ?	year	-7.479350566864
# how much is the glacial engineering course per year ?	$ 8000	-8.2633075714111
# what kind of engineering course is covered by the university of kansas ?	nus	-13.651232719421
