# %% [markdown]
# # `convert_text_to_opennmt_format.py`

# %%
import json
import copy
from pycorenlp import StanfordCoreNLP
from sys import argv
from pprint import pprint as pprint

nlp = StanfordCoreNLP('http://localhost:9000')

# %%
# !cat ./data/ner_features
with open('data/sample_short.txt', 'r') as myfile:
    text = myfile.read()
print(text)
# Out:
# DATE	1
# DURATION	2
# LOCATION	3
# MISC	4
# MONEY	5
# NUMBER	6
# O	7
# ORDINAL	8
# ORGANIZATION	9
# PADDING	10
# PERCENT	11
# PERSON	12
# TIME	13
# Singapore was declared independent on 9 August 1965.
# National Service lasts two years.
# The tuition fee for Stanford engineering course is $8000 per year.

# %%
output = nlp.annotate(text, properties={
    'annotators': 'tokenize,ssplit,pos,ner',
    'outputFormat': 'json'}
)
if type(output) == str:
    output =json.loads(output, encoding='utf-8', strict=False)
pprint(output)
# Out:
# {'sentences': [{'index': 0,
#                 'parse': 'SENTENCE_SKIPPED_OR_UNPARSABLE',
#                 'tokens': [{'after': ' ',
#                             'before': '',
#                             'characterOffsetBegin': 0,
#                             'characterOffsetEnd': 9,
#                             'index': 1,
#                             'lemma': 'Singapore',
#                             'ner': 'LOCATION',
#                             'originalText': 'Singapore',
#                             'pos': 'NNP',
#                             'word': 'Singapore'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 10,
#                             'characterOffsetEnd': 13,
#                             'index': 2,
#                             'lemma': 'be',
#                             'ner': 'O',
#                             'originalText': 'was',
#                             'pos': 'VBD',
#                             'word': 'was'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 14,
#                             'characterOffsetEnd': 22,
#                             'index': 3,
#                             'lemma': 'declare',
#                             'ner': 'O',
#                             'originalText': 'declared',
#                             'pos': 'VBN',
#                             'word': 'declared'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 23,
#                             'characterOffsetEnd': 34,
#                             'index': 4,
#                             'lemma': 'independent',
#                             'ner': 'O',
#                             'originalText': 'independent',
#                             'pos': 'JJ',
#                             'word': 'independent'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 35,
#                             'characterOffsetEnd': 37,
#                             'index': 5,
#                             'lemma': 'on',
#                             'ner': 'O',
#                             'originalText': 'on',
#                             'pos': 'IN',
#                             'word': 'on'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 38,
#                             'characterOffsetEnd': 39,
#                             'index': 6,
#                             'lemma': '9',
#                             'ner': 'DATE',
#                             'normalizedNER': '1965-08-09',
#                             'originalText': '9',
#                             'pos': 'CD',
#                             'timex': {'tid': 't1',
#                                       'type': 'DATE',
#                                       'value': '1965-08-09'},
#                             'word': '9'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 40,
#                             'characterOffsetEnd': 46,
#                             'index': 7,
#                             'lemma': 'August',
#                             'ner': 'DATE',
#                             'normalizedNER': '1965-08-09',
#                             'originalText': 'August',
#                             'pos': 'NNP',
#                             'timex': {'tid': 't1',
#                                       'type': 'DATE',
#                                       'value': '1965-08-09'},
#                             'word': 'August'},
#                            {'after': '',
#                             'before': ' ',
#                             'characterOffsetBegin': 47,
#                             'characterOffsetEnd': 51,
#                             'index': 8,
#                             'lemma': '1965',
#                             'ner': 'DATE',
#                             'normalizedNER': '1965-08-09',
#                             'originalText': '1965',
#                             'pos': 'CD',
#                             'timex': {'tid': 't1',
#                                       'type': 'DATE',
#                                       'value': '1965-08-09'},
#                             'word': '1965'},
#                            {'after': ' \n',
#                             'before': '',
#                             'characterOffsetBegin': 51,
#                             'characterOffsetEnd': 52,
#                             'index': 9,
#                             'lemma': '.',
#                             'ner': 'O',
#                             'originalText': '.',
#                             'pos': '.',
#                             'word': '.'}]},
#                {'index': 1,
#                 'parse': 'SENTENCE_SKIPPED_OR_UNPARSABLE',
#                 'tokens': [{'after': ' ',
#                             'before': ' \n',
#                             'characterOffsetBegin': 54,
#                             'characterOffsetEnd': 62,
#                             'index': 1,
#                             'lemma': 'National',
#                             'ner': 'ORGANIZATION',
#                             'originalText': 'National',
#                             'pos': 'NNP',
#                             'word': 'National'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 63,
#                             'characterOffsetEnd': 70,
#                             'index': 2,
#                             'lemma': 'Service',
#                             'ner': 'ORGANIZATION',
#                             'originalText': 'Service',
#                             'pos': 'NNP',
#                             'word': 'Service'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 71,
#                             'characterOffsetEnd': 76,
#                             'index': 3,
#                             'lemma': 'last',
#                             'ner': 'O',
#                             'originalText': 'lasts',
#                             'pos': 'VBZ',
#                             'word': 'lasts'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 77,
#                             'characterOffsetEnd': 80,
#                             'index': 4,
#                             'lemma': 'two',
#                             'ner': 'DURATION',
#                             'normalizedNER': 'P2Y',
#                             'originalText': 'two',
#                             'pos': 'CD',
#                             'timex': {'tid': 't2',
#                                       'type': 'DURATION',
#                                       'value': 'P2Y'},
#                             'word': 'two'},
#                            {'after': '',
#                             'before': ' ',
#                             'characterOffsetBegin': 81,
#                             'characterOffsetEnd': 86,
#                             'index': 5,
#                             'lemma': 'year',
#                             'ner': 'DURATION',
#                             'normalizedNER': 'P2Y',
#                             'originalText': 'years',
#                             'pos': 'NNS',
#                             'timex': {'tid': 't2',
#                                       'type': 'DURATION',
#                                       'value': 'P2Y'},
#                             'word': 'years'},
#                            {'after': ' \n',
#                             'before': '',
#                             'characterOffsetBegin': 86,
#                             'characterOffsetEnd': 87,
#                             'index': 6,
#                             'lemma': '.',
#                             'ner': 'O',
#                             'originalText': '.',
#                             'pos': '.',
#                             'word': '.'}]},
#                {'index': 2,
#                 'parse': 'SENTENCE_SKIPPED_OR_UNPARSABLE',
#                 'tokens': [{'after': ' ',
#                             'before': ' \n',
#                             'characterOffsetBegin': 89,
#                             'characterOffsetEnd': 92,
#                             'index': 1,
#                             'lemma': 'the',
#                             'ner': 'O',
#                             'originalText': 'The',
#                             'pos': 'DT',
#                             'word': 'The'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 93,
#                             'characterOffsetEnd': 100,
#                             'index': 2,
#                             'lemma': 'tuition',
#                             'ner': 'O',
#                             'originalText': 'tuition',
#                             'pos': 'NN',
#                             'word': 'tuition'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 101,
#                             'characterOffsetEnd': 104,
#                             'index': 3,
#                             'lemma': 'fee',
#                             'ner': 'O',
#                             'originalText': 'fee',
#                             'pos': 'NN',
#                             'word': 'fee'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 105,
#                             'characterOffsetEnd': 108,
#                             'index': 4,
#                             'lemma': 'for',
#                             'ner': 'O',
#                             'originalText': 'for',
#                             'pos': 'IN',
#                             'word': 'for'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 109,
#                             'characterOffsetEnd': 117,
#                             'index': 5,
#                             'lemma': 'Stanford',
#                             'ner': 'ORGANIZATION',
#                             'originalText': 'Stanford',
#                             'pos': 'NNP',
#                             'word': 'Stanford'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 118,
#                             'characterOffsetEnd': 129,
#                             'index': 6,
#                             'lemma': 'engineering',
#                             'ner': 'O',
#                             'originalText': 'engineering',
#                             'pos': 'NN',
#                             'word': 'engineering'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 130,
#                             'characterOffsetEnd': 136,
#                             'index': 7,
#                             'lemma': 'course',
#                             'ner': 'O',
#                             'originalText': 'course',
#                             'pos': 'NN',
#                             'word': 'course'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 137,
#                             'characterOffsetEnd': 139,
#                             'index': 8,
#                             'lemma': 'be',
#                             'ner': 'O',
#                             'originalText': 'is',
#                             'pos': 'VBZ',
#                             'word': 'is'},
#                            {'after': '',
#                             'before': ' ',
#                             'characterOffsetBegin': 140,
#                             'characterOffsetEnd': 141,
#                             'index': 9,
#                             'lemma': '$',
#                             'ner': 'MONEY',
#                             'normalizedNER': '$8000.0',
#                             'originalText': '$',
#                             'pos': '$',
#                             'word': '$'},
#                            {'after': ' ',
#                             'before': '',
#                             'characterOffsetBegin': 141,
#                             'characterOffsetEnd': 145,
#                             'index': 10,
#                             'lemma': '8000',
#                             'ner': 'MONEY',
#                             'normalizedNER': '$8000.0',
#                             'originalText': '8000',
#                             'pos': 'CD',
#                             'word': '8000'},
#                            {'after': ' ',
#                             'before': ' ',
#                             'characterOffsetBegin': 146,
#                             'characterOffsetEnd': 149,
#                             'index': 11,
#                             'lemma': 'per',
#                             'ner': 'O',
#                             'originalText': 'per',
#                             'pos': 'IN',
#                             'word': 'per'},
#                            {'after': '',
#                             'before': ' ',
#                             'characterOffsetBegin': 150,
#                             'characterOffsetEnd': 154,
#                             'index': 12,
#                             'lemma': 'year',
#                             'ner': 'DURATION',
#                             'normalizedNER': 'P1Y',
#                             'originalText': 'year',
#                             'pos': 'NN',
#                             'timex': {'tid': 't3',
#                                       'type': 'DURATION',
#                                       'value': 'P1Y'},
#                             'word': 'year'},
#                            {'after': '',
#                             'before': '',
#                             'characterOffsetBegin': 154,
#                             'characterOffsetEnd': 155,
#                             'index': 13,
#                             'lemma': '.',
#                             'ner': 'O',
#                             'originalText': '.',
#                             'pos': '.',
#                             'word': '.'}]}]}

# %%
def get_possible_ans_tags(ner_features_path='data/ner_features'):
    with open(ner_features_path, 'r') as f:
        possible_ans_tags = [line.split('\t')[0] for line in f]
    possible_ans_tags = [tag for tag in possible_ans_tags if tag != 'O']
    possible_ans_tags.append('CD')
    possible_ans_tags = set(possible_ans_tags)
    return possible_ans_tags

possible_ans_tags = get_possible_ans_tags()
pprint(possible_ans_tags)
# Out:
# {'CD',
#  'DATE',
#  'DURATION',
#  'LOCATION',
#  'MISC',
#  'MONEY',
#  'NUMBER',
#  'ORDINAL',
#  'ORGANIZATION',
#  'PADDING',
#  'PERCENT',
#  'PERSON',
#  'TIME'}

# %%
def get_featured_sents(corenlp_output):
    sents = []
    for sentence in corenlp_output['sentences']:
        sent_start_ind = sentence['index']
        sent = []
        for token in sentence['tokens']:
            token_start_ind = token['index']
            word = token['originalText']
            lower_word = word.lower()
            if (word[0] == word[0].upper() and word[0] != word[0].lower()):
                case_tag = 'UP'
            else:
                case_tag = 'LOW'
            ner_tag = token['ner']
            pos_tag = token['pos']
            sent.append(({'token': lower_word, 'ner': ner_tag, 'case_tag': case_tag, 'pos_tag': pos_tag}))
        sents.append(sent)
    return sents
sents = get_featured_sents(output)
pprint(sents)
# Out:
# [[{'case_tag': 'UP', 'ner': 'LOCATION', 'pos_tag': 'NNP', 'token': 'singapore'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'VBD', 'token': 'was'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'VBN', 'token': 'declared'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'JJ', 'token': 'independent'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'IN', 'token': 'on'},
#   {'case_tag': 'LOW', 'ner': 'DATE', 'pos_tag': 'CD', 'token': '9'},
#   {'case_tag': 'UP', 'ner': 'DATE', 'pos_tag': 'NNP', 'token': 'august'},
#   {'case_tag': 'LOW', 'ner': 'DATE', 'pos_tag': 'CD', 'token': '1965'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': '.', 'token': '.'}],
#  [{'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'national'},
#   {'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'service'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'VBZ', 'token': 'lasts'},
#   {'case_tag': 'LOW', 'ner': 'DURATION', 'pos_tag': 'CD', 'token': 'two'},
#   {'case_tag': 'LOW', 'ner': 'DURATION', 'pos_tag': 'NNS', 'token': 'years'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': '.', 'token': '.'}],
#  [{'case_tag': 'UP', 'ner': 'O', 'pos_tag': 'DT', 'token': 'the'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'NN', 'token': 'tuition'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'NN', 'token': 'fee'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'IN', 'token': 'for'},
#   {'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'stanford'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'NN', 'token': 'engineering'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'NN', 'token': 'course'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'VBZ', 'token': 'is'},
#   {'case_tag': 'LOW', 'ner': 'MONEY', 'pos_tag': '$', 'token': '$'},
#   {'case_tag': 'LOW', 'ner': 'MONEY', 'pos_tag': 'CD', 'token': '8000'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': 'IN', 'token': 'per'},
#   {'case_tag': 'LOW', 'ner': 'DURATION', 'pos_tag': 'NN', 'token': 'year'},
#   {'case_tag': 'LOW', 'ner': 'O', 'pos_tag': '.', 'token': '.'}]]

# %%
def add_answers_tag(sents, possible_ans_tags):
    for sent in sents:
        ans_tag = 'O'
        for token in sent:
            if token['ner'] in possible_ans_tags or token['pos_tag'] in possible_ans_tags:
                if ans_tag == 'B' or ans_tag == 'I':
                    ans_tag = 'I'
                else:
                    ans_tag = 'B'
            else:
                ans_tag = 'O'
            token['ans_tag'] = ans_tag
add_answers_tag(sents, possible_ans_tags)
pprint(sents)
# Out:
# [[{'ans_tag': 'B',
#    'case_tag': 'UP',
#    'ner': 'LOCATION',
#    'pos_tag': 'NNP',
#    'token': 'singapore'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBD',
#    'token': 'was'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBN',
#    'token': 'declared'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'JJ',
#    'token': 'independent'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'on'},
#   {'ans_tag': 'B',
#    'case_tag': 'LOW',
#    'ner': 'DATE',
#    'pos_tag': 'CD',
#    'token': '9'},
#   {'ans_tag': 'I',
#    'case_tag': 'UP',
#    'ner': 'DATE',
#    'pos_tag': 'NNP',
#    'token': 'august'},
#   {'ans_tag': 'I',
#    'case_tag': 'LOW',
#    'ner': 'DATE',
#    'pos_tag': 'CD',
#    'token': '1965'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': '.',
#    'token': '.'}],
#  [{'ans_tag': 'B',
#    'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'national'},
#   {'ans_tag': 'I',
#    'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'service'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBZ',
#    'token': 'lasts'},
#   {'ans_tag': 'B',
#    'case_tag': 'LOW',
#    'ner': 'DURATION',
#    'pos_tag': 'CD',
#    'token': 'two'},
#   {'ans_tag': 'I',
#    'case_tag': 'LOW',
#    'ner': 'DURATION',
#    'pos_tag': 'NNS',
#    'token': 'years'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': '.',
#    'token': '.'}],
#  [{'ans_tag': 'O',
#    'case_tag': 'UP',
#    'ner': 'O',
#    'pos_tag': 'DT',
#    'token': 'the'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'tuition'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'fee'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'for'},
#   {'ans_tag': 'B',
#    'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'stanford'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'engineering'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'course'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBZ',
#    'token': 'is'},
#   {'ans_tag': 'B',
#    'case_tag': 'LOW',
#    'ner': 'MONEY',
#    'pos_tag': '$',
#    'token': '$'},
#   {'ans_tag': 'I',
#    'case_tag': 'LOW',
#    'ner': 'MONEY',
#    'pos_tag': 'CD',
#    'token': '8000'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'per'},
#   {'ans_tag': 'B',
#    'case_tag': 'LOW',
#    'ner': 'DURATION',
#    'pos_tag': 'NN',
#    'token': 'year'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': '.',
#    'token': '.'}]]

# %%
def copy_sent_with_one_ans(sent, begin_ind, end_ind):
    new_sent = copy.deepcopy(sent)
    for ind, token in enumerate(new_sent):
        if ind < begin_ind or ind > end_ind:
            token['ans_tag'] = 'O'
    return new_sent

def separate_and_duplicate_ans_sents(sents):
    new_sents = []
    for sent in sents:
        begin_ind, end_ind = None, None
        for ind, token in enumerate(sent):
            if token['ans_tag'] == 'B':
                begin_ind = ind
            elif token['ans_tag'] == 'I':
                continue
            else:
                if begin_ind is not None:
                    end_ind = ind - 1
                    new_sent = copy_sent_with_one_ans(sent, begin_ind, end_ind)
                    begin_ind = None
                    new_sents.append(new_sent)
                else:
                    begin_ind, end_ind = None, None
    return new_sents
sents = separate_and_duplicate_ans_sents(sents)
pprint(sents)
# Out:
# [[{'ans_tag': 'B',
#    'case_tag': 'UP',
#    'ner': 'LOCATION',
#    'pos_tag': 'NNP',
#    'token': 'singapore'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBD',
#    'token': 'was'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBN',
#    'token': 'declared'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'JJ',
#    'token': 'independent'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'on'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'DATE',
#    'pos_tag': 'CD',
#    'token': '9'},
#   {'ans_tag': 'O',
#    'case_tag': 'UP',
#    'ner': 'DATE',
#    'pos_tag': 'NNP',
#    'token': 'august'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'DATE',
#    'pos_tag': 'CD',
#    'token': '1965'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': '.',
#    'token': '.'}],
#  [{'ans_tag': 'O',
#    'case_tag': 'UP',
#    'ner': 'LOCATION',
#    'pos_tag': 'NNP',
#    'token': 'singapore'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBD',
#    'token': 'was'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBN',
#    'token': 'declared'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'JJ',
#    'token': 'independent'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'on'},
#   {'ans_tag': 'B',
#    'case_tag': 'LOW',
#    'ner': 'DATE',
#    'pos_tag': 'CD',
#    'token': '9'},
#   {'ans_tag': 'I',
#    'case_tag': 'UP',
#    'ner': 'DATE',
#    'pos_tag': 'NNP',
#    'token': 'august'},
#   {'ans_tag': 'I',
#    'case_tag': 'LOW',
#    'ner': 'DATE',
#    'pos_tag': 'CD',
#    'token': '1965'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': '.',
#    'token': '.'}],
#  [{'ans_tag': 'B',
#    'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'national'},
#   {'ans_tag': 'I',
#    'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'service'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBZ',
#    'token': 'lasts'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'DURATION',
#    'pos_tag': 'CD',
#    'token': 'two'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'DURATION',
#    'pos_tag': 'NNS',
#    'token': 'years'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': '.',
#    'token': '.'}],
#  [{'ans_tag': 'O',
#    'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'national'},
#   {'ans_tag': 'O',
#    'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'service'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBZ',
#    'token': 'lasts'},
#   {'ans_tag': 'B',
#    'case_tag': 'LOW',
#    'ner': 'DURATION',
#    'pos_tag': 'CD',
#    'token': 'two'},
#   {'ans_tag': 'I',
#    'case_tag': 'LOW',
#    'ner': 'DURATION',
#    'pos_tag': 'NNS',
#    'token': 'years'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': '.',
#    'token': '.'}],
#  [{'ans_tag': 'O',
#    'case_tag': 'UP',
#    'ner': 'O',
#    'pos_tag': 'DT',
#    'token': 'the'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'tuition'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'fee'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'for'},
#   {'ans_tag': 'B',
#    'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'stanford'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'engineering'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'course'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBZ',
#    'token': 'is'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'MONEY',
#    'pos_tag': '$',
#    'token': '$'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'MONEY',
#    'pos_tag': 'CD',
#    'token': '8000'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'per'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'DURATION',
#    'pos_tag': 'NN',
#    'token': 'year'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': '.',
#    'token': '.'}],
#  [{'ans_tag': 'O',
#    'case_tag': 'UP',
#    'ner': 'O',
#    'pos_tag': 'DT',
#    'token': 'the'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'tuition'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'fee'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'for'},
#   {'ans_tag': 'O',
#    'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'stanford'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'engineering'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'course'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBZ',
#    'token': 'is'},
#   {'ans_tag': 'B',
#    'case_tag': 'LOW',
#    'ner': 'MONEY',
#    'pos_tag': '$',
#    'token': '$'},
#   {'ans_tag': 'I',
#    'case_tag': 'LOW',
#    'ner': 'MONEY',
#    'pos_tag': 'CD',
#    'token': '8000'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'per'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'DURATION',
#    'pos_tag': 'NN',
#    'token': 'year'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': '.',
#    'token': '.'}],
#  [{'ans_tag': 'O',
#    'case_tag': 'UP',
#    'ner': 'O',
#    'pos_tag': 'DT',
#    'token': 'the'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'tuition'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'fee'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'for'},
#   {'ans_tag': 'O',
#    'case_tag': 'UP',
#    'ner': 'ORGANIZATION',
#    'pos_tag': 'NNP',
#    'token': 'stanford'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'engineering'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'NN',
#    'token': 'course'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'VBZ',
#    'token': 'is'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'MONEY',
#    'pos_tag': '$',
#    'token': '$'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'MONEY',
#    'pos_tag': 'CD',
#    'token': '8000'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': 'IN',
#    'token': 'per'},
#   {'ans_tag': 'B',
#    'case_tag': 'LOW',
#    'ner': 'DURATION',
#    'pos_tag': 'NN',
#    'token': 'year'},
#   {'ans_tag': 'O',
#    'case_tag': 'LOW',
#    'ner': 'O',
#    'pos_tag': '.',
#    'token': '.'}]]

# %%
def convert_sents_to_opennmt(sents):
    featured_sents = []
    for sent in sents:
        featured_source_tokens = []
        for token in sent:
            featured_source_token = "{}￨{}￨{}￨{}￨{}".format(
                token['token'],
                token['ans_tag'],
                token['case_tag'],
                token['pos_tag'],
                token['ner']
            )
            featured_source_tokens.append(featured_source_token)
        featured_sents.append(" ".join(featured_source_tokens))
    return featured_sents
opennmt_sents = convert_sents_to_opennmt(sents)
for sent in opennmt_sents:
    print(sent)
    # this output is piped to get qnas.py
# Out:
# singapore￨B￨UP￨NNP￨LOCATION was￨O￨LOW￨VBD￨O declared￨O￨LOW￨VBN￨O independent￨O￨LOW￨JJ￨O on￨O￨LOW￨IN￨O 9￨O￨LOW￨CD￨DATE august￨O￨UP￨NNP￨DATE 1965￨O￨LOW￨CD￨DATE .￨O￨LOW￨.￨O
# singapore￨O￨UP￨NNP￨LOCATION was￨O￨LOW￨VBD￨O declared￨O￨LOW￨VBN￨O independent￨O￨LOW￨JJ￨O on￨O￨LOW￨IN￨O 9￨B￨LOW￨CD￨DATE august￨I￨UP￨NNP￨DATE 1965￨I￨LOW￨CD￨DATE .￨O￨LOW￨.￨O
# national￨B￨UP￨NNP￨ORGANIZATION service￨I￨UP￨NNP￨ORGANIZATION lasts￨O￨LOW￨VBZ￨O two￨O￨LOW￨CD￨DURATION years￨O￨LOW￨NNS￨DURATION .￨O￨LOW￨.￨O
# national￨O￨UP￨NNP￨ORGANIZATION service￨O￨UP￨NNP￨ORGANIZATION lasts￨O￨LOW￨VBZ￨O two￨B￨LOW￨CD￨DURATION years￨I￨LOW￨NNS￨DURATION .￨O￨LOW￨.￨O
# the￨O￨UP￨DT￨O tuition￨O￨LOW￨NN￨O fee￨O￨LOW￨NN￨O for￨O￨LOW￨IN￨O stanford￨B￨UP￨NNP￨ORGANIZATION engineering￨O￨LOW￨NN￨O course￨O￨LOW￨NN￨O is￨O￨LOW￨VBZ￨O $￨O￨LOW￨$￨MONEY 8000￨O￨LOW￨CD￨MONEY per￨O￨LOW￨IN￨O year￨O￨LOW￨NN￨DURATION .￨O￨LOW￨.￨O
# the￨O￨UP￨DT￨O tuition￨O￨LOW￨NN￨O fee￨O￨LOW￨NN￨O for￨O￨LOW￨IN￨O stanford￨O￨UP￨NNP￨ORGANIZATION engineering￨O￨LOW￨NN￨O course￨O￨LOW￨NN￨O is￨O￨LOW￨VBZ￨O $￨B￨LOW￨$￨MONEY 8000￨I￨LOW￨CD￨MONEY per￨O￨LOW￨IN￨O year￨O￨LOW￨NN￨DURATION .￨O￨LOW￨.￨O
# the￨O￨UP￨DT￨O tuition￨O￨LOW￨NN￨O fee￨O￨LOW￨NN￨O for￨O￨LOW￨IN￨O stanford￨O￨UP￨NNP￨ORGANIZATION engineering￨O￨LOW￨NN￨O course￨O￨LOW￨NN￨O is￨O￨LOW￨VBZ￨O $￨O￨LOW￨$￨MONEY 8000￨O￨LOW￨CD￨MONEY per￨O￨LOW￨IN￨O year￨B￨LOW￨NN￨DURATION .￨O￨LOW￨.￨O

# %% [markdown]
# # `get_qna.py`

# %%
# -*- coding: utf-8 -*-
import zmq, sys, json
from signal import signal, SIGPIPE, SIG_DFL

# %%
data = [{"src": line} for line in opennmt_sents]

# %%
class ConnectionHandler:
    def __init__(self):
        signal(SIGPIPE, SIG_DFL)
        self.sock = zmq.Context().socket(zmq.REQ)
        self.sock.connect("tcp://127.0.0.1:5556")

    def __call__(self, data):
        self.sock.send_string(json.dumps(data))
        recieved = json.loads(str(self.sock.recv(), "utf-8"), encoding='utf-8', strict=False)
        print("Output from openmnt \n")
        pprint(recieved)
        print("\n\n\n\n")
        recieved = [(row[0]['tgt'], row[0]['pred_score'], row[0]['src']) for row in recieved]
        print("Output that is relevant")
        pprint(recieved)
        print("\n\n\n\n")
        return get_with_answers(recieved)

# does this merely process the answers?
def get_with_answers(recieved):
    answers = []
    for _, _, src in recieved:
        tokens = src.split(' ')
        answer = []
        for token in tokens:
            features = token.split('￨')
            word = features[0]
            ans_tag = features[1]
            if ans_tag == 'B' or ans_tag == 'I':
                answer.append(word)
            elif answer:
                break
        answers.append(' '.join(answer))
    return [(recieved[i][0], answers[i], recieved[i][1]) for i in range(len(recieved))]

# %%
connect = ConnectionHandler()
received = connect(data)

for target, answer, score in sorted(received, key=lambda x: x[2], reverse=True):
    print("{}\t{}\t{}".format(target, answer, score))
# Out:
# Output from openmnt
#
# [[{'attn': [[0.99102300405502,
#              0.0037460965104401,
#              0.00092615053290501,
#              0.0012628746917471,
#              0.0025424077175558,
#              5.9968009736622e-05,
#              9.4836314019631e-06,
#              1.78015743586e-05,
#              0.00041221251012757],
#             [1.4661324030385e-06,
#              0.11344105005264,
#              0.88650673627853,
#              4.9313908675686e-05,
#              3.0605920642301e-07,
#              1.1565532531677e-08,
#              7.572441007575e-10,
#              7.8667972136515e-10,
#              1.1150099226143e-06],
#             [2.7094037591269e-07,
#              3.2391406421084e-05,
#              0.99922150373459,
#              0.00074580480577424,
#              1.8678381508153e-08,
#              1.2291422324395e-09,
#              3.6530442559801e-10,
#              6.4651023423679e-10,
#              2.116089881099e-08],
#             [2.3581554486896e-09,
#              2.4916758434301e-07,
#              0.0009753170888871,
#              0.9987370967865,
#              0.00028412160463631,
#              2.6336823566453e-07,
#              1.7061615835701e-06,
#              2.8964401987963e-09,
#              1.2592954590218e-06],
#             [1.5035520846141e-06,
#              1.4223842015326e-07,
#              1.8817043212493e-07,
#              0.0018646729877219,
#              0.99474132061005,
#              0.0001140228487202,
#              0.0017437329515815,
#              5.8753630582942e-05,
#              0.0014756926102564],
#             [4.7093141830601e-08,
#              1.2389735903895e-09,
#              9.5551962175922e-11,
#              9.1972708560206e-07,
#              0.00034336946555413,
#              0.082107245922089,
#              0.91647708415985,
#              0.00085514836246148,
#              0.00021616918093059],
#             [2.1579257478144e-11,
#              5.9335947266703e-10,
#              3.6148729842811e-11,
#              1.9218457381065e-10,
#              9.1533074453309e-08,
#              0.00012899552530143,
#              0.66274684667587,
#              0.33343282341957,
#              0.0036912539508194],
#             [2.3454252429111e-10,
#              1.1369419850027e-09,
#              8.6837733184741e-12,
#              1.2685259093148e-11,
#              8.1667383966533e-09,
#              2.5693594579934e-05,
#              0.016346469521523,
#              0.7476704120636,
#              0.23595744371414]],
#    'n_best': 1,
#    'pred_score': -4.4853830337524,
#    'src': 'singapore￨B￨UP￨NNP￨LOCATION was￨O￨LOW￨VBD￨O declared￨O￨LOW￨VBN￨O '
#           'independent￨O￨LOW￨JJ￨O on￨O￨LOW￨IN￨O 9￨O￨LOW￨CD￨DATE '
#           'august￨O￨UP￨NNP￨DATE 1965￨O￨LOW￨CD￨DATE .￨O￨LOW￨.￨O',
#    'tgt': 'who was declared independent on august august ?'}],
#  [{'attn': [[1.6530357527245e-07,
#              1.3102518096275e-05,
#              2.3222685285873e-06,
#              9.6305084298365e-05,
#              0.36869889497757,
#              0.62471556663513,
#              0.0051984563469887,
#              0.0011300054611638,
#              0.00014519559044857],
#             [2.0879342628177e-05,
#              0.96669679880142,
#              0.032933689653873,
#              3.1041345209815e-05,
#              1.66073687069e-06,
#              7.2613613610883e-07,
#              3.38092633001e-07,
#              1.9084016003035e-06,
#              0.00031293745269068],
#             [0.999795794487,
#              0.00013142140232958,
#              2.6011899535661e-05,
#              4.5748929551337e-05,
#              9.8915736712613e-11,
#              4.7891860616156e-11,
#              1.3933732390115e-08,
#              2.5224125010936e-09,
#              9.7891063433053e-07],
#             [3.1518451578449e-05,
#              0.018513156101108,
#              0.98086529970169,
#              0.00058973551495001,
#              6.8277344666967e-08,
#              7.1846968478784e-12,
#              8.2571154774724e-12,
#              3.3293826029457e-11,
#              2.3246984426351e-07],
#             [0.007732599042356,
#              0.00031546610989608,
#              0.0099724167957902,
#              0.98190969228745,
#              6.4794011223057e-07,
#              8.7164547801777e-10,
#              1.1041336733797e-08,
#              1.0751961099231e-08,
#              6.9148780312389e-05],
#             [0.00022477231686935,
#              0.0074281692504883,
#              0.017943764105439,
#              0.030264919623733,
#              0.88656413555145,
#              6.1231713743837e-07,
#              1.519592274235e-06,
#              2.54872907135e-06,
#              0.057569604367018]],
#    'n_best': 1,
#    'pred_score': -3.1612322330475,
#    'src': 'singapore￨O￨UP￨NNP￨LOCATION was￨O￨LOW￨VBD￨O declared￨O￨LOW￨VBN￨O '
#           'independent￨O￨LOW￨JJ￨O on￨O￨LOW￨IN￨O 9￨B￨LOW￨CD￨DATE '
#           'august￨I￨UP￨NNP￨DATE 1965￨I￨LOW￨CD￨DATE .￨O￨LOW￨.￨O',
#    'tgt': 'when did singapore declare independence ?'}],
#  [{'attn': [[0.9678236246109,
#              0.015795120969415,
#              0.00090423692017794,
#              0.0037361790891737,
#              0.00052611844148487,
#              0.011214765720069],
#             [0.047067042440176,
#              0.95012730360031,
#              0.0019540381617844,
#              0.00072605995228514,
#              1.5726462152088e-05,
#              0.00010977641795762],
#             [0.0032685492187738,
#              0.00016759015852585,
#              0.40615943074226,
#              0.58141243457794,
#              0.00046162403305061,
#              0.0085303671658039],
#             [0.013724490068853,
#              0.032944645732641,
#              0.015790743753314,
#              0.48544102907181,
#              0.084292151033878,
#              0.36780697107315],
#             [0.0001965967239812,
#              5.8031491789734e-06,
#              0.024554988369346,
#              0.11041966080666,
#              0.038425505161285,
#              0.82639741897583],
#             [0.0028607796411961,
#              8.5153391410131e-05,
#              0.014051825739443,
#              0.96724545955658,
#              0.0086728781461716,
#              0.0070839119143784],
#             [0.00020589854102582,
#              0.00032341919722967,
#              0.0002913429052569,
#              0.038614895194769,
#              0.95690113306046,
#              0.0036633417475969],
#             [2.8109925551689e-06,
#              2.8158260079181e-07,
#              0.0057291886769235,
#              0.0016058393521234,
#              0.02544897980988,
#              0.96721285581589]],
#    'n_best': 1,
#    'pred_score': -5.5310859680176,
#    'src': 'national￨B￨UP￨NNP￨ORGANIZATION service￨I￨UP￨NNP￨ORGANIZATION '
#           'lasts￨O￨LOW￨VBZ￨O two￨O￨LOW￨CD￨DURATION years￨O￨LOW￨NNS￨DURATION '
#           '.￨O￨LOW￨.￨O',
#    'tgt': 'what is another name for two years ?'}],
#  [{'attn': [[1.8870126950787e-05,
#              3.8405196391977e-06,
#              0.0043128291144967,
#              0.9785470366478,
#              0.0086305914446712,
#              0.0084868222475052],
#             [1.0863064892064e-09,
#              1.1549450285031e-10,
#              1.9296567899119e-08,
#              0.18149344623089,
#              0.8147822022438,
#              0.0037243440747261],
#             [1.6617825622234e-06,
#              1.3209521476654e-08,
#              1.3553504984998e-08,
#              0.00029782261117361,
#              0.99829089641571,
#              0.0014095937367529],
#             [5.5821550404289e-07,
#              3.5528320285749e-09,
#              0.12995047867298,
#              0.0010022901697084,
#              0.021040726453066,
#              0.8480059504509],
#             [0.99982708692551,
#              0.00016883872740436,
#              3.9108872442739e-06,
#              2.1683129250438e-11,
#              2.0967573510777e-10,
#              1.8524963252275e-07],
#             [6.6811400756706e-05,
#              0.99993252754211,
#              6.536568548654e-07,
#              2.7521144000883e-13,
#              1.3059090484338e-13,
#              2.3908149765495e-12],
#             [2.3791338676915e-08,
#              5.8443299622013e-07,
#              0.99999934434891,
#              9.0369750571639e-10,
#              1.4388818261879e-11,
#              2.0804913347661e-08],
#             [0.00037703558336943,
#              9.8628515843302e-06,
#              0.97224491834641,
#              0.0017672660760581,
#              0.00025295984232798,
#              0.025347929447889]],
#    'n_best': 1,
#    'pred_score': -2.7501549720764,
#    'src': 'national￨O￨UP￨NNP￨ORGANIZATION service￨O￨UP￨NNP￨ORGANIZATION '
#           'lasts￨O￨LOW￨VBZ￨O two￨B￨LOW￨CD￨DURATION years￨I￨LOW￨NNS￨DURATION '
#           '.￨O￨LOW￨.￨O',
#    'tgt': 'how many years does national service last ?'}],
#  [{'attn': [[0.015126335434616,
#              0.0026842919178307,
#              0.0059446338564157,
#              0.27518045902252,
#              0.69957393407822,
#              7.2816178544599e-06,
#              7.4786170443986e-05,
#              0.00028191751334816,
#              5.5114895076258e-05,
#              1.5564753994113e-05,
#              3.8925525586819e-05,
#              0.00029933388577774,
#              0.00071741000283509],
#             [3.7339782466006e-07,
#              8.5341326894195e-08,
#              3.0682851814845e-08,
#              5.1329624284335e-07,
#              0.99990326166153,
#              2.9858554626117e-05,
#              4.313817782986e-07,
#              5.4977448598947e-05,
#              9.7942811407847e-06,
#              1.1924504939032e-08,
#              1.0563901753358e-08,
#              5.5374459861923e-07,
#              7.0602027335553e-08],
#             [1.9648905436043e-06,
#              7.655094123038e-06,
#              1.168438572563e-07,
#              3.3563274826065e-08,
#              0.010531424544752,
#              0.96231424808502,
#              0.027074510231614,
#              5.2563173085218e-05,
#              7.5105185715074e-06,
#              1.0292801562173e-06,
#              6.9893025056444e-07,
#              7.9653773354948e-06,
#              2.7739710617425e-07],
#             [4.4418611651054e-06,
#              4.4149378481961e-06,
#              1.6054869774962e-05,
#              1.7185475371662e-05,
#              2.1077459678054e-05,
#              0.0005896560032852,
#              0.99858671426773,
#              0.00068060460034758,
#              1.1331692917338e-07,
#              3.4122241032719e-08,
#              2.9961511245347e-05,
#              3.0508048439515e-05,
#              1.9229903045925e-05],
#             [7.4168547143927e-06,
#              2.4419722421953e-07,
#              3.113277216471e-06,
#              3.9680107875029e-06,
#              1.0909470802289e-06,
#              4.0218372987511e-07,
#              0.010211913846433,
#              0.98829847574234,
#              0.00097980571445078,
#              9.6157318694168e-06,
#              9.192799552693e-06,
#              1.1953672583331e-05,
#              0.00046282305265777],
#             [0.175706833601,
#              0.0038133079651743,
#              0.005665217526257,
#              0.00023270203382708,
#              3.2057523640106e-06,
#              4.4546527533385e-06,
#              0.0015113413101062,
#              0.019186722114682,
#              0.39696323871613,
#              0.34783867001534,
#              0.00084489490836859,
#              0.00067903916351497,
#              0.047550391405821],
#             [0.017905103042722,
#              0.00020883927936666,
#              0.00022098018962424,
#              0.0010281205177307,
#              0.00013243917783257,
#              1.6284324374283e-05,
#              0.001955381128937,
#              0.0093061914667487,
#              0.057022929191589,
#              0.0098710060119629,
#              0.034995101392269,
#              0.021032093092799,
#              0.84630554914474],
#             [7.228524191305e-05,
#              0.00016186440188903,
#              4.0607105802337e-06,
#              8.3940476542921e-06,
#              3.6564927086147e-06,
#              2.6737990992842e-05,
#              0.00015616859309375,
#              3.8043359040785e-07,
#              1.1583498235268e-05,
#              0.00015674048336223,
#              0.0065564126707613,
#              0.99096930027008,
#              0.0018724420806393],
#             [0.0091217653825879,
#              4.8779635108076e-05,
#              0.00026478330255486,
#              0.0035402690991759,
#              1.6292744930979e-07,
#              8.6784912127769e-06,
#              0.001682472997345,
#              0.0019248843891546,
#              2.433796726109e-05,
#              1.5643123333575e-05,
#              0.0070775845088065,
#              0.0015455061802641,
#              0.9747451543808]],
#    'n_best': 1,
#    'pred_score': -9.6145076751709,
#    'src': 'the￨O￨UP￨DT￨O tuition￨O￨LOW￨NN￨O fee￨O￨LOW￨NN￨O for￨O￨LOW￨IN￨O '
#           'stanford￨B￨UP￨NNP￨ORGANIZATION engineering￨O￨LOW￨NN￨O '
#           'course￨O￨LOW￨NN￨O is￨O￨LOW￨VBZ￨O $￨O￨LOW￨$￨MONEY '
#           '8000￨O￨LOW￨CD￨MONEY per￨O￨LOW￨IN￨O year￨O￨LOW￨NN￨DURATION '
#           '.￨O￨LOW￨.￨O',
#    'tgt': 'how many engineering course is there each year ?'}],
#  [{'attn': [[0.0088524697348475,
#              0.00067287584533915,
#              0.00045309081906453,
#              0.001520118676126,
#              0.0002173676766688,
#              1.5565752846669e-06,
#              0.0012605538358912,
#              0.054958663880825,
#              0.88643395900726,
#              0.043919783085585,
#              0.00032544494024478,
#              0.00039041033596732,
#              0.00099367764778435],
#             [4.4763413598048e-07,
#              9.8662823688755e-08,
#              3.748575228002e-09,
#              3.3395124443558e-09,
#              3.6925891322426e-07,
#              3.507912182954e-09,
#              4.6241690476734e-09,
#              1.9696475646924e-05,
#              0.98460328578949,
#              0.015357746742666,
#              8.5832552940701e-06,
#              9.5594923550379e-06,
#              2.0707109626983e-07],
#             [0.00030727114062756,
#              6.872777157696e-05,
#              5.1103156692989e-06,
#              2.0981007764931e-05,
#              0.00011625325714704,
#              4.7193535124279e-07,
#              0.00044500894728117,
#              0.020278526470065,
#              0.034337423741817,
#              0.75220340490341,
#              0.15181297063828,
#              0.026233220472932,
#              0.014170638285577],
#             [0.11961437761784,
#              0.0015655225142837,
#              0.015484372153878,
#              0.0073859305121005,
#              0.85326367616653,
#              3.7069487461849e-06,
#              7.1881704570842e-06,
#              1.1710592843883e-05,
#              2.1203889843946e-07,
#              1.9324230379425e-05,
#              4.2317224142607e-05,
#              5.2322167903185e-05,
#              0.0025493332650512],
#             [0.018509624525905,
#              0.00020065892022103,
#              0.00068656605435535,
#              0.0099142482504249,
#              5.2937186410418e-05,
#              0.0001010293563013,
#              0.027662385255098,
#              0.00049992918502539,
#              8.0716299635242e-06,
#              2.4914825189626e-05,
#              0.014863405376673,
#              0.0095606986433268,
#              0.91791552305222],
#             [0.0023696068674326,
#              0.0075061987154186,
#              0.0006866761832498,
#              0.00036690881825052,
#              0.053222328424454,
#              0.00081420637434348,
#              0.0015636803582311,
#              5.7857744195644e-07,
#              1.5236886383718e-06,
#              2.8458231099648e-05,
#              0.00026191625511274,
#              0.93217039108276,
#              0.0010075536556542],
#             [0.056016836315393,
#              0.00027369728195481,
#              0.030189028009772,
#              0.58985209465027,
#              0.0047255354002118,
#              0.0031350534409285,
#              0.019239852204919,
#              0.0030924994498491,
#              7.5799654553066e-08,
#              2.7562890636545e-08,
#              1.7545196897117e-05,
#              7.9259727499448e-05,
#              0.29337853193283]],
#    'n_best': 1,
#    'pred_score': -5.6697635650635,
#    'src': 'the￨O￨UP￨DT￨O tuition￨O￨LOW￨NN￨O fee￨O￨LOW￨NN￨O for￨O￨LOW￨IN￨O '
#           'stanford￨O￨UP￨NNP￨ORGANIZATION engineering￨O￨LOW￨NN￨O '
#           'course￨O￨LOW￨NN￨O is￨O￨LOW￨VBZ￨O $￨B￨LOW￨$￨MONEY '
#           '8000￨I￨LOW￨CD￨MONEY per￨O￨LOW￨IN￨O year￨O￨LOW￨NN￨DURATION '
#           '.￨O￨LOW￨.￨O',
#    'tgt': 'how much is tuition per year ?'}],
#  [{'attn': [[0.0013989590806887,
#              8.5338157077786e-05,
#              6.9814894231968e-05,
#              0.00026737505686469,
#              2.8093618311686e-05,
#              3.5388228525335e-07,
#              0.00024670391576365,
#              0.0022833559196442,
#              0.00087969313608482,
#              0.00019657850498334,
#              0.056897778064013,
#              0.93492811918259,
#              0.0027178199961782],
#             [2.6089310267707e-06,
#              3.3051844638976e-07,
#              1.6450320217132e-08,
#              3.0417687924e-08,
#              1.7149336599687e-06,
#              4.7553026405467e-08,
#              5.8472232922213e-07,
#              0.0013772463425994,
#              0.0015749976737425,
#              7.9406891018152e-07,
#              1.8250613720738e-05,
#              0.99692368507385,
#              9.971688996302e-05],
#             [0.00014938510139473,
#              1.6555144384256e-06,
#              1.7520696928841e-05,
#              4.6550536353607e-05,
#              1.0152649565498e-06,
#              2.8915050620526e-07,
#              0.00092689524171874,
#              0.95662188529968,
#              0.0051160007715225,
#              7.9062658187468e-05,
#              0.0012350556207821,
#              0.0051762447692454,
#              0.030628427863121],
#             [0.14824657142162,
#              0.001294894143939,
#              0.012338791973889,
#              0.0099042961373925,
#              0.81950348615646,
#              1.3097386499794e-06,
#              4.7878925215628e-06,
#              0.00019942391372751,
#              0.0036405583377928,
#              0.0044303685426712,
#              7.4767137903109e-07,
#              2.3776792090757e-08,
#              0.00043475022539496],
#             [0.095805816352367,
#              0.0010441774502397,
#              0.0071232938207686,
#              0.076421782374382,
#              0.00023901264648885,
#              0.00033828025334515,
#              0.096399441361427,
#              0.0016709205228835,
#              0.004970679525286,
#              0.016998553648591,
#              0.51292264461517,
#              0.0035455322358757,
#              0.18251985311508],
#             [0.0056323357857764,
#              0.015781663358212,
#              0.0020224766340107,
#              0.0011115769157186,
#              0.030484613031149,
#              0.0027021034620702,
#              0.019828194752336,
#              1.191367937281e-05,
#              0.00022661671391688,
#              0.0048560132272542,
#              0.0070330514572561,
#              0.90873515605927,
#              0.0015742833493277],
#             [0.071022689342499,
#              0.00025631938478909,
#              0.035249564796686,
#              0.77859991788864,
#              0.0028521490748972,
#              0.0017478103982285,
#              0.058194626122713,
#              0.045215584337711,
#              0.00035767769441009,
#              9.3925031251274e-05,
#              1.6968249838101e-05,
#              2.9284663582985e-07,
#              0.0063924961723387]],
#    'n_best': 1,
#    'pred_score': -6.8855409622192,
#    'src': 'the￨O￨UP￨DT￨O tuition￨O￨LOW￨NN￨O fee￨O￨LOW￨NN￨O for￨O￨LOW￨IN￨O '
#           'stanford￨O￨UP￨NNP￨ORGANIZATION engineering￨O￨LOW￨NN￨O '
#           'course￨O￨LOW￨NN￨O is￨O￨LOW￨VBZ￨O $￨O￨LOW￨$￨MONEY '
#           '8000￨O￨LOW￨CD￨MONEY per￨O￨LOW￨IN￨O year￨B￨LOW￨NN￨DURATION '
#           '.￨O￨LOW￨.￨O',
#    'tgt': 'how long is tuition per year ?'}]]
#
#
#
#
#
# Output that is relevant
# [('who was declared independent on august august ?',
#   -4.4853830337524,
#   'singapore￨B￨UP￨NNP￨LOCATION was￨O￨LOW￨VBD￨O declared￨O￨LOW￨VBN￨O '
#   'independent￨O￨LOW￨JJ￨O on￨O￨LOW￨IN￨O 9￨O￨LOW￨CD￨DATE august￨O￨UP￨NNP￨DATE '
#   '1965￨O￨LOW￨CD￨DATE .￨O￨LOW￨.￨O'),
#  ('when did singapore declare independence ?',
#   -3.1612322330475,
#   'singapore￨O￨UP￨NNP￨LOCATION was￨O￨LOW￨VBD￨O declared￨O￨LOW￨VBN￨O '
#   'independent￨O￨LOW￨JJ￨O on￨O￨LOW￨IN￨O 9￨B￨LOW￨CD￨DATE august￨I￨UP￨NNP￨DATE '
#   '1965￨I￨LOW￨CD￨DATE .￨O￨LOW￨.￨O'),
#  ('what is another name for two years ?',
#   -5.5310859680176,
#   'national￨B￨UP￨NNP￨ORGANIZATION service￨I￨UP￨NNP￨ORGANIZATION '
#   'lasts￨O￨LOW￨VBZ￨O two￨O￨LOW￨CD￨DURATION years￨O￨LOW￨NNS￨DURATION '
#   '.￨O￨LOW￨.￨O'),
#  ('how many years does national service last ?',
#   -2.7501549720764,
#   'national￨O￨UP￨NNP￨ORGANIZATION service￨O￨UP￨NNP￨ORGANIZATION '
#   'lasts￨O￨LOW￨VBZ￨O two￨B￨LOW￨CD￨DURATION years￨I￨LOW￨NNS￨DURATION '
#   '.￨O￨LOW￨.￨O'),
#  ('how many engineering course is there each year ?',
#   -9.6145076751709,
#   'the￨O￨UP￨DT￨O tuition￨O￨LOW￨NN￨O fee￨O￨LOW￨NN￨O for￨O￨LOW￨IN￨O '
#   'stanford￨B￨UP￨NNP￨ORGANIZATION engineering￨O￨LOW￨NN￨O course￨O￨LOW￨NN￨O '
#   'is￨O￨LOW￨VBZ￨O $￨O￨LOW￨$￨MONEY 8000￨O￨LOW￨CD￨MONEY per￨O￨LOW￨IN￨O '
#   'year￨O￨LOW￨NN￨DURATION .￨O￨LOW￨.￨O'),
#  ('how much is tuition per year ?',
#   -5.6697635650635,
#   'the￨O￨UP￨DT￨O tuition￨O￨LOW￨NN￨O fee￨O￨LOW￨NN￨O for￨O￨LOW￨IN￨O '
#   'stanford￨O￨UP￨NNP￨ORGANIZATION engineering￨O￨LOW￨NN￨O course￨O￨LOW￨NN￨O '
#   'is￨O￨LOW￨VBZ￨O $￨B￨LOW￨$￨MONEY 8000￨I￨LOW￨CD￨MONEY per￨O￨LOW￨IN￨O '
#   'year￨O￨LOW￨NN￨DURATION .￨O￨LOW￨.￨O'),
#  ('how long is tuition per year ?',
#   -6.8855409622192,
#   'the￨O￨UP￨DT￨O tuition￨O￨LOW￨NN￨O fee￨O￨LOW￨NN￨O for￨O￨LOW￨IN￨O '
#   'stanford￨O￨UP￨NNP￨ORGANIZATION engineering￨O￨LOW￨NN￨O course￨O￨LOW￨NN￨O '
#   'is￨O￨LOW￨VBZ￨O $￨O￨LOW￨$￨MONEY 8000￨O￨LOW￨CD￨MONEY per￨O￨LOW￨IN￨O '
#   'year￨B￨LOW￨NN￨DURATION .￨O￨LOW￨.￨O')]
#
#
#
#
#
# how many years does national service last ?	two years	-2.7501549720764
# when did singapore declare independence ?	9 august 1965	-3.1612322330475
# who was declared independent on august august ?	singapore	-4.4853830337524
# what is another name for two years ?	national service	-5.5310859680176
# how much is tuition per year ?	$ 8000	-5.6697635650635
# how long is tuition per year ?	year	-6.8855409622192
# how many engineering course is there each year ?	stanford	-9.6145076751709
